# %%
import csv

with open("titanic.csv") as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        print(row.keys())
# Out:
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# dict_keys([None])
# ...
